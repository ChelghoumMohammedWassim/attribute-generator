# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from gaGen import GenGeneticAlgorithm
import copy

# %%
def evaluate(X_train : pd.DataFrame, y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame, random_state = None):
    
    clf = DecisionTreeClassifier(random_state= random_state)
    
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)
    precision = precision_score(predictions,y_test, average='macro')
    f1 = f1_score(predictions,y_test, average='macro')
    recall = recall_score(predictions,y_test, average='macro')
    
    return {"precision":precision, "f1":f1, "recall":recall}

# %%
dataset_name= "vehicule"

data = pd.read_csv(f"../Datasets/{dataset_name}.csv")

data.head(10)
# Out:
#    COMPACTNESS  CIRCULARITY  'DISTANCE CIRCULARITY'  'RADIUS RATIO'  \
# 0           95           48                      83             178
# 1           91           41                      84             141
# 2          104           50                     106             209
# 3           93           41                      82             159
# 4           85           44                      70             205
# 5          107           57                     106             172
# 6           97           43                      73             173
# 7           90           43                      66             157
# 8           86           34                      62             140
# 9           93           44                      98             197
#
#    'PR.AXIS ASPECT RATIO'  'MAX.LENGTH ASPECT RATIO'  'SCATTER RATIO'  \
# 0                      72                         10              162
# 1                      57                          9              149
# 2                      66                         10              207
# 3                      63                          9              144
# 4                     103                         52              149
# 5                      50                          6              255
# 6                      65                          6              153
# 7                      65                          9              137
# 8                      61                          7              122
# 9                      62                         11              183
#
#    ELONGATEDNESS  'PR.AXIS RECTANGULARITY'  'MAX.LENGTH RECTANGULARITY'  \
# 0             42                        20                          159
# 1             45                        19                          143
# 2             32                        23                          158
# 3             46                        19                          143
# 4             45                        19                          144
# 5             26                        28                          169
# 6             42                        19                          143
# 7             48                        18                          146
# 8             54                        17                          127
# 9             36                        22                          146
#
#    'SCALED VARIANCE_MAJOR'  'SCALED VARIANCE_MINOR'  \
# 0                      176                      379
# 1                      170                      330
# 2                      223                      635
# 3                      160                      309
# 4                      241                      325
# 5                      280                      957
# 6                      176                      361
# 7                      162                      281
# 8                      141                      223
# 9                      202                      505
#
#    'SCALED RADIUS OF GYRATION'  'SKEWNESS ABOUT_MAJOR'  \
# 0                          184                      70
# 1                          158                      72
# 2                          220                      73
# 3                          127                      63
# 4                          188                     127
# 5                          264                      85
# 6                          172                      66
# 7                          164                      67
# 8                          112                      64
# 9                          152                      64
#
#    'SKEWNESS ABOUT_MINOR'  'KURTOSIS ABOUT_MAJOR'  'KURTOSIS ABOUT_MINOR'  \
# 0                       6                      16                     187
# 1                       9                      14                     189
# 2                      14                       9                     188
# 3                       6                      10                     199
# 4                       9                      11                     180
# 5                       5                       9                     181
# 6                      13                       1                     200
# 7                       3                       3                     193
# 8                       2                      14                     200
# 9                       4                      14                     195
#
#    'HOLLOWS RATIO' Class
# 0              197   van
# 1              199   van
# 2              196  saab
# 3              207   van
# 4              183   bus
# 5              183   bus
# 6              204   bus
# 7              202   van
# 8              208   van
# 9              204  saab

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state= 42)

before_scores= []
selected_scores= []
all_scores = []
columns_number= []

for index,(train_index, test_index) in enumerate(skf.split(X, y)):
    
    fold_x_train =X.iloc[train_index]
    fold_y_train = y.iloc[train_index]
    
    fold_x_test =X.iloc[test_index]
    fold_y_test = y.iloc[test_index]
    
    score_before = evaluate(fold_x_train, fold_y_train, fold_x_test, fold_y_test)
    before_scores.append(score_before)
    
    print(f'''For the original data:
    Columns : {fold_x_train.columns}
    Columns Number : {len(fold_x_train.columns)} 
    precision : {score_before["precision"]}
    f1        : {score_before["f1"]}
    recall    : {score_before["recall"]}
          ''')
    print("Ga Gen started with inputs ......")
    ga= GenGeneticAlgorithm(
        X_train= fold_x_train,
        X_test= fold_x_test,
        y_train= fold_y_train,
        y_test= fold_y_test,
        rnd_state=None
    )

    selected_new_X_train , selected_new_X_test, all__new_X_train ,all_new_X_test = ga.run(population_size= 30, generation_limit= 50, mutation_probability= 0.1)
    
    print("Ga Gen finished ...")

    score_after= evaluate(all__new_X_train, fold_y_train, all_new_X_test, fold_y_test)
    all_scores.append(score_after)
    
    print(f'''\nFor the new generated data with gaGen without selection:
    Columns : {all_new_X_test.columns}
    Columns Number : {len(all_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
    ''')
    score_after= evaluate(selected_new_X_train, fold_y_train, selected_new_X_test, fold_y_test)
    selected_scores.append(score_after)
    
    columns_number.append(len(selected_new_X_test.columns))
    
    print(f'''\nFor the new generated data with gaGen with selection:
    Columns : {selected_new_X_test.columns}
    Columns Number : {len(selected_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
--------------------------------------------------------------------------------------''')
# Out:
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.7076298701298701
#     f1        : 0.7048980862659991
#     recall    : 0.7046750398724082
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7217532467532468
#     f1        : 0.7215972439479277
#     recall    : 0.7269375361480623
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''MAX.LENGTH ASPECT RATIO'', 'ELONGATEDNESS',
#        ''SCALED VARIANCE_MINOR'', ''SKEWNESS ABOUT_MAJOR'',
#        ''SKEWNESS ABOUT_MINOR'', ''KURTOSIS ABOUT_MAJOR'',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=235)
#     Columns Number : 235
#     precision : 0.7053571428571428
#     f1        : 0.7071540484583962
#     recall    : 0.7126301607599561
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.789448051948052
#     f1        : 0.7889368418456681
#     recall    : 0.7903352130325815
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7899891774891774
#     f1        : 0.7880166014737766
#     recall    : 0.7894762845849802
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['CIRCULARITY', ''DISTANCE CIRCULARITY'', ''RADIUS RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''MAX.LENGTH RECTANGULARITY'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MINOR'', ''KURTOSIS ABOUT_MAJOR'',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'SKEWNESS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average'],
#       dtype='object', length=224)
#     Columns Number : 224
#     precision : 0.7785714285714286
#     f1        : 0.7748152254249815
#     recall    : 0.7758387445887446
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.72754329004329
#     f1        : 0.724924924924925
#     recall    : 0.7290374519813206
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7661796536796537
#     f1        : 0.7601593573534929
#     recall    : 0.7641369047619048
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index([''DISTANCE CIRCULARITY'', ''RADIUS RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED RADIUS OF GYRATION'', ''SKEWNESS ABOUT_MINOR'',
#        'COMPACTNESS_CIRCULARITY___addition',
#        'COMPACTNESS_CIRCULARITY___average',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average'],
#       dtype='object', length=232)
#     Columns Number : 232
#     precision : 0.777435064935065
#     f1        : 0.7767021485423912
#     recall    : 0.7772556390977444
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.686038961038961
#     f1        : 0.6808035047914739
#     recall    : 0.6847718253968254
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7667207792207791
#     f1        : 0.7683179316265212
#     recall    : 0.7720238095238096
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['COMPACTNESS', ''RADIUS RATIO'', 'ELONGATEDNESS',
#        ''PR.AXIS RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SKEWNESS ABOUT_MAJOR'', ''HOLLOWS RATIO'',
#        'COMPACTNESS_CIRCULARITY___addition',
#        'COMPACTNESS_CIRCULARITY___multiplication',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=228)
#     Columns Number : 228
#     precision : 0.7185064935064934
#     f1        : 0.7201453032017816
#     recall    : 0.726921470342523
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.7125541125541125
#     f1        : 0.7091947348044909
#     recall    : 0.7067805383022774
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7608225108225108
#     f1        : 0.7506770975290544
#     recall    : 0.7459273182957394
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index([''DISTANCE CIRCULARITY'', ''RADIUS RATIO'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MINOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO'',
#        'COMPACTNESS_CIRCULARITY___addition',
#        'COMPACTNESS_CIRCULARITY___average',
#        'COMPACTNESS_'DISTANCE CIRCULARITY'___addition',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'SKEWNESS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average'],
#       dtype='object', length=245)
#     Columns Number : 245
#     precision : 0.8051406926406925
#     f1        : 0.8035777407463516
#     recall    : 0.8047462406015037
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.6625
#     f1        : 0.6720571949710117
#     recall    : 0.6992274966412897
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.6994588744588744
#     f1        : 0.6970342522974101
#     recall    : 0.6984903381642512
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['CIRCULARITY', ''DISTANCE CIRCULARITY'', ''RADIUS RATIO'',
#        ''MAX.LENGTH ASPECT RATIO'', ''SCATTER RATIO'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition'],
#       dtype='object', length=229)
#     Columns Number : 229
#     precision : 0.7465909090909091
#     f1        : 0.7430212517978475
#     recall    : 0.744722857869311
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.6541125541125541
#     f1        : 0.6542205950600732
#     recall    : 0.6545454545454545
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7612554112554112
#     f1        : 0.7614091512799811
#     recall    : 0.765622009569378
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index([''DISTANCE CIRCULARITY'', ''PR.AXIS ASPECT RATIO'',
#        ''MAX.LENGTH ASPECT RATIO'', ''PR.AXIS RECTANGULARITY'',
#        ''SCALED VARIANCE_MAJOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MINOR'', ''KURTOSIS ABOUT_MAJOR'',
#        ''KURTOSIS ABOUT_MINOR'', 'COMPACTNESS_CIRCULARITY___addition',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MAJOR'___multiplication',
#        ''SKEWNESS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average'],
#       dtype='object', length=219)
#     Columns Number : 219
#     precision : 0.6397186147186147
#     f1        : 0.6489750001996364
#     recall    : 0.6748376623376623
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.7368506493506494
#     f1        : 0.7445565695565696
#     recall    : 0.7564935064935066
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.7833333333333332
#     f1        : 0.7905684754521963
#     recall    : 0.8049242424242424
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['COMPACTNESS', ''MAX.LENGTH ASPECT RATIO'', ''SCATTER RATIO'',
#        'ELONGATEDNESS', ''SCALED VARIANCE_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO'',
#        'COMPACTNESS_CIRCULARITY___addition',
#        'COMPACTNESS_'DISTANCE CIRCULARITY'___addition',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average'],
#       dtype='object', length=245)
#     Columns Number : 245
#     precision : 0.7470238095238095
#     f1        : 0.7524801587301587
#     recall    : 0.7727561657767608
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.7510281385281385
#     f1        : 0.7512445887445888
#     recall    : 0.754896505096734
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.8326839826839827
#     f1        : 0.8313310845874416
#     recall    : 0.8330263157894736
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['COMPACTNESS', ''PR.AXIS ASPECT RATIO'', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED RADIUS OF GYRATION'', ''SKEWNESS ABOUT_MAJOR'',
#        ''SKEWNESS ABOUT_MINOR'', ''KURTOSIS ABOUT_MAJOR'',
#        ''KURTOSIS ABOUT_MINOR'',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition'],
#       dtype='object', length=240)
#     Columns Number : 240
#     precision : 0.726082251082251
#     f1        : 0.7247976073841076
#     recall    : 0.7252642475754604
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'', ''SCALED VARIANCE_MAJOR'',
#        ''SCALED VARIANCE_MINOR'', ''SCALED RADIUS OF GYRATION'',
#        ''SKEWNESS ABOUT_MAJOR'', ''SKEWNESS ABOUT_MINOR'',
#        ''KURTOSIS ABOUT_MAJOR'', ''KURTOSIS ABOUT_MINOR'', ''HOLLOWS RATIO''],
#       dtype='object')
#     Columns Number : 18
#     precision : 0.7546992481203006
#     f1        : 0.7554750834178194
#     recall    : 0.7583333333333333
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['COMPACTNESS', 'CIRCULARITY', ''DISTANCE CIRCULARITY'',
#        ''RADIUS RATIO'', ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH ASPECT RATIO'',
#        ''SCATTER RATIO'', 'ELONGATEDNESS', ''PR.AXIS RECTANGULARITY'',
#        ''MAX.LENGTH RECTANGULARITY'',
#        ...
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___average',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=477)
#     Columns Number : 477
#     precision : 0.6944634313055366
#     f1        : 0.689461921452846
#     recall    : 0.6852484472049689
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['COMPACTNESS', ''DISTANCE CIRCULARITY'', ''RADIUS RATIO'',
#        ''PR.AXIS ASPECT RATIO'', ''MAX.LENGTH RECTANGULARITY'',
#        ''SCALED RADIUS OF GYRATION'', ''SKEWNESS ABOUT_MINOR'',
#        'COMPACTNESS_CIRCULARITY___average',
#        'COMPACTNESS_'DISTANCE CIRCULARITY'___average',
#        'COMPACTNESS_'RADIUS RATIO'___average',
#        ...
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''SKEWNESS ABOUT_MAJOR'_'HOLLOWS RATIO'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MAJOR'___multiplication',
#        ''SKEWNESS ABOUT_MINOR'_'KURTOSIS ABOUT_MINOR'___average',
#        ''SKEWNESS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication',
#        ''KURTOSIS ABOUT_MAJOR'_'KURTOSIS ABOUT_MINOR'___addition',
#        ''KURTOSIS ABOUT_MAJOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___addition',
#        ''KURTOSIS ABOUT_MINOR'_'HOLLOWS RATIO'___multiplication'],
#       dtype='object', length=234)
#     Columns Number : 234
#     precision : 0.669771018455229
#     f1        : 0.6794621135046668
#     recall    : 0.6986274509803921
# --------------------------------------------------------------------------------------

# %%
sums = {}
counts = {}

for score in before_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Original Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Original Data:
# precision: 0.7182404875825928
# f1: 0.7186312124382619
# recall: 0.7239096364695732

# %%
sums = {}
counts = {}

for score in all_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated without fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated without fs Data:
# precision: 0.7576660401002505
# f1: 0.7558573117000649
# recall: 0.7585813206466809

# %%
sums = {}
counts = {}

for score in selected_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated with fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated with fs Data:
# precision: 0.7314197425381636
# f1: 0.733113059799032
# recall: 0.7413600639930058

# %%
print(f"Columns generation: {np.mean(columns_number)}")
# Out:
# Columns generation: 233.1
