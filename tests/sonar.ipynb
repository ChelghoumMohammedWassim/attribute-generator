# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from gaGen import GenGeneticAlgorithm
import copy

# %%
def evaluate(X_train : pd.DataFrame, y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame, random_state = None):
    
    clf = DecisionTreeClassifier(random_state= random_state)
    
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)
    precision = precision_score(predictions,y_test, average='macro')
    f1 = f1_score(predictions,y_test, average='macro')
    recall = recall_score(predictions,y_test, average='macro')
    
    return {"precision":precision, "f1":f1, "recall":recall}

# %%
dataset_name= "sonar
"

data = pd.read_csv(f"../Datasets/{dataset_name}.csv")

data.head(10)
# Out:
#    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0       0.0200       0.0371       0.0428       0.0207       0.0954
# 1       0.0453       0.0523       0.0843       0.0689       0.1183
# 2       0.0262       0.0582       0.1099       0.1083       0.0974
# 3       0.0100       0.0171       0.0623       0.0205       0.0205
# 4       0.0762       0.0666       0.0481       0.0394       0.0590
# 5       0.0286       0.0453       0.0277       0.0174       0.0384
# 6       0.0317       0.0956       0.1321       0.1408       0.1674
# 7       0.0519       0.0548       0.0842       0.0319       0.1158
# 8       0.0223       0.0375       0.0484       0.0475       0.0647
# 9       0.0164       0.0173       0.0347       0.0070       0.0187
#
#    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0       0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1       0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2       0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3       0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4       0.0649       0.1209       0.2467       0.3564        0.4459  ...
# 5       0.0990       0.1201       0.1833       0.2105        0.3039  ...
# 6       0.1710       0.0731       0.1401       0.2083        0.3513  ...
# 7       0.0922       0.1027       0.0613       0.1465        0.2838  ...
# 8       0.0591       0.0753       0.0098       0.0684        0.1487  ...
# 9       0.0671       0.1056       0.0697       0.0962        0.0251  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# 0        0.0027        0.0065        0.0159        0.0072        0.0167
# 1        0.0084        0.0089        0.0048        0.0094        0.0191
# 2        0.0232        0.0166        0.0095        0.0180        0.0244
# 3        0.0121        0.0036        0.0150        0.0085        0.0073
# 4        0.0031        0.0054        0.0105        0.0110        0.0015
# 5        0.0045        0.0014        0.0038        0.0013        0.0089
# 6        0.0201        0.0248        0.0131        0.0070        0.0138
# 7        0.0081        0.0120        0.0045        0.0121        0.0097
# 8        0.0145        0.0128        0.0145        0.0058        0.0049
# 9        0.0090        0.0223        0.0179        0.0084        0.0068
#
#    attribute_57  attribute_58  attribute_59  attribute_60  Class
# 0        0.0180        0.0084        0.0090        0.0032   Rock
# 1        0.0140        0.0049        0.0052        0.0044   Rock
# 2        0.0316        0.0164        0.0095        0.0078   Rock
# 3        0.0050        0.0044        0.0040        0.0117   Rock
# 4        0.0072        0.0048        0.0107        0.0094   Rock
# 5        0.0057        0.0027        0.0051        0.0062   Rock
# 6        0.0092        0.0143        0.0036        0.0103   Rock
# 7        0.0085        0.0047        0.0048        0.0053   Rock
# 8        0.0065        0.0093        0.0059        0.0022   Rock
# 9        0.0032        0.0035        0.0056        0.0040   Rock
#
# [10 rows x 61 columns]

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state= 42)

before_scores= []
selected_scores= []
all_scores = []
columns_number= []

for index,(train_index, test_index) in enumerate(skf.split(X, y)):
    
    fold_x_train =X.iloc[train_index]
    fold_y_train = y.iloc[train_index]
    
    fold_x_test =X.iloc[test_index]
    fold_y_test = y.iloc[test_index]
    
    score_before = evaluate(fold_x_train, fold_y_train, fold_x_test, fold_y_test)
    before_scores.append(score_before)
    
    print(f'''For the original data:
    Columns : {fold_x_train.columns}
    Columns Number : {len(fold_x_train.columns)} 
    precision : {score_before["precision"]}
    f1        : {score_before["f1"]}
    recall    : {score_before["recall"]}
          ''')
    print("Ga Gen started with inputs ......")
    ga= GenGeneticAlgorithm(
        X_train= fold_x_train,
        X_test= fold_x_test,
        y_train= fold_y_train,
        y_test= fold_y_test,
    )

    selected_new_X_train , selected_new_X_test, all__new_X_train ,all_new_X_test = ga.run(population_size= 20, generation_limit= 10, mutation_probability= 0.1)
    
    print("Ga Gen finished ...")

    score_after= evaluate(all__new_X_train, fold_y_train, all_new_X_test, fold_y_test)
    all_scores.append(score_after)
    
    print(f'''\nFor the new generated data with gaGen without selection:
    Columns : {all_new_X_test.columns}
    Columns Number : {len(all_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
    ''')
    score_after= evaluate(selected_new_X_train, fold_y_train, selected_new_X_test, fold_y_test)
    selected_scores.append(score_after)
    
    columns_number.append(len(selected_new_X_test.columns))
    
    print(f'''\nFor the new generated data with gaGen with selection:
    Columns : {selected_new_X_test.columns}
    Columns Number : {len(selected_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
--------------------------------------------------------------------------------------''')
# Out:
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.7545454545454545
#     f1        : 0.7529411764705882
#     recall    : 0.7857142857142857
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.8545454545454545
#     f1        : 0.8558352402745995
#     recall    : 0.8611111111111112
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_1', 'attribute_3', 'attribute_4', 'attribute_5',
#        'attribute_8', 'attribute_11', 'attribute_13', 'attribute_17',
#        'attribute_20', 'attribute_21',
#        ...
#        'attribute_55_attribute_56___average',
#        'attribute_55_attribute_59___addition',
#        'attribute_56_attribute_57___average',
#        'attribute_56_attribute_58___average',
#        'attribute_56_attribute_59___average',
#        'attribute_56_attribute_60___multiplication',
#        'attribute_57_attribute_58___addition',
#        'attribute_57_attribute_58___multiplication',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_59_attribute_60___average'],
#       dtype='object', length=1720)
#     Columns Number : 1720
#     precision : 0.7090909090909091
#     f1        : 0.7083333333333333
#     recall    : 0.7211538461538461
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.5681818181818181
#     f1        : 0.5675057208237986
#     recall    : 0.5694444444444444
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.7727272727272727
#     f1        : 0.7529411764705882
#     recall    : 0.8333333333333333
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_3', 'attribute_5', 'attribute_6', 'attribute_9',
#        'attribute_13', 'attribute_16', 'attribute_18', 'attribute_19',
#        'attribute_20', 'attribute_21',
#        ...
#        'attribute_56_attribute_60___average',
#        'attribute_56_attribute_60___multiplication',
#        'attribute_57_attribute_58___addition',
#        'attribute_57_attribute_59___multiplication',
#        'attribute_57_attribute_60___average',
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication'],
#       dtype='object', length=2689)
#     Columns Number : 2689
#     precision : 0.6090909090909091
#     f1        : 0.5961538461538461
#     recall    : 0.6333333333333333
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.8
#     f1        : 0.7980769230769231
#     recall    : 0.8666666666666667
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.8545454545454545
#     f1        : 0.8558352402745995
#     recall    : 0.8611111111111112
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_12',
#        'attribute_13', 'attribute_17',
#        ...
#        'attribute_56_attribute_60___multiplication',
#        'attribute_57_attribute_58___addition',
#        'attribute_57_attribute_58___multiplication',
#        'attribute_57_attribute_60___addition',
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition'],
#       dtype='object', length=2655)
#     Columns Number : 2655
#     precision : 0.9045454545454545
#     f1        : 0.9045454545454545
#     recall    : 0.9045454545454545
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.8090909090909091
#     f1        : 0.8090909090909091
#     recall    : 0.8090909090909091
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.8136363636363637
#     f1        : 0.8090909090909091
#     recall    : 0.8194444444444444
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_4', 'attribute_5', 'attribute_6', 'attribute_7',
#        'attribute_9', 'attribute_11', 'attribute_12', 'attribute_13',
#        'attribute_14', 'attribute_15',
#        ...
#        'attribute_57_attribute_58___multiplication',
#        'attribute_57_attribute_59___addition',
#        'attribute_57_attribute_59___average',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=2653)
#     Columns Number : 2653
#     precision : 0.7727272727272727
#     f1        : 0.7529411764705882
#     recall    : 0.8333333333333333
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.5227272727272727
#     f1        : 0.5227272727272727
#     recall    : 0.5227272727272727
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.7090909090909091
#     f1        : 0.7083333333333333
#     recall    : 0.7211538461538461
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_2', 'attribute_4', 'attribute_5', 'attribute_10',
#        'attribute_14', 'attribute_15', 'attribute_18', 'attribute_20',
#        'attribute_23', 'attribute_24',
#        ...
#        'attribute_56_attribute_60___addition',
#        'attribute_56_attribute_60___average',
#        'attribute_57_attribute_59___addition',
#        'attribute_57_attribute_59___average',
#        'attribute_57_attribute_60___addition',
#        'attribute_57_attribute_60___average',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=2688)
#     Columns Number : 2688
#     precision : 0.7136363636363636
#     f1        : 0.7136363636363636
#     recall    : 0.7136363636363636
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.7181818181818183
#     f1        : 0.7136363636363636
#     recall    : 0.7222222222222222
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.9545454545454546
#     f1        : 0.9523809523809523
#     recall    : 0.9545454545454546
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_4', 'attribute_5', 'attribute_6', 'attribute_7',
#        'attribute_10', 'attribute_11', 'attribute_12', 'attribute_13',
#        'attribute_18', 'attribute_22',
#        ...
#        'attribute_57_attribute_58___average',
#        'attribute_57_attribute_59___addition',
#        'attribute_57_attribute_59___average',
#        'attribute_57_attribute_59___multiplication',
#        'attribute_57_attribute_60___addition',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average'],
#       dtype='object', length=2667)
#     Columns Number : 2667
#     precision : 0.9545454545454546
#     f1        : 0.9523809523809523
#     recall    : 0.9545454545454546
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.7181818181818183
#     f1        : 0.7136363636363636
#     recall    : 0.7222222222222222
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.8
#     f1        : 0.7980769230769231
#     recall    : 0.8666666666666667
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_5',
#        'attribute_6', 'attribute_7', 'attribute_9', 'attribute_10',
#        'attribute_11', 'attribute_12',
#        ...
#        'attribute_53_attribute_55___addition',
#        'attribute_53_attribute_56___addition',
#        'attribute_53_attribute_56___multiplication',
#        'attribute_53_attribute_57___addition',
#        'attribute_53_attribute_58___multiplication',
#        'attribute_54_attribute_58___multiplication',
#        'attribute_54_attribute_59___average',
#        'attribute_55_attribute_57___multiplication',
#        'attribute_56_attribute_57___addition',
#        'attribute_56_attribute_58___average'],
#       dtype='object', length=598)
#     Columns Number : 598
#     precision : 0.759090909090909
#     f1        : 0.7597254004576659
#     recall    : 0.7638888888888888
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.6944444444444444
#     f1        : 0.6971153846153846
#     recall    : 0.7142857142857143
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.9444444444444444
#     f1        : 0.9505882352941176
#     recall    : 0.9615384615384616
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_5', 'attribute_9', 'attribute_10', 'attribute_13',
#        'attribute_14', 'attribute_15', 'attribute_21', 'attribute_22',
#        'attribute_23', 'attribute_28',
#        ...
#        'attribute_56_attribute_60___multiplication',
#        'attribute_57_attribute_58___addition',
#        'attribute_57_attribute_58___average',
#        'attribute_57_attribute_60___addition',
#        'attribute_57_attribute_60___average',
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_60___addition',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average'],
#       dtype='object', length=2408)
#     Columns Number : 2408
#     precision : 0.8888888888888888
#     f1        : 0.8990384615384616
#     recall    : 0.9285714285714286
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.8535353535353536
#     f1        : 0.849624060150376
#     recall    : 0.8500000000000001
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.5505050505050505
#     f1        : 0.5488721804511278
#     recall    : 0.55
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_7', 'attribute_8', 'attribute_9',
#        'attribute_10', 'attribute_11',
#        ...
#        'attribute_57_attribute_59___addition',
#        'attribute_57_attribute_60___addition',
#        'attribute_57_attribute_60___average',
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=687)
#     Columns Number : 687
#     precision : 0.7070707070707071
#     f1        : 0.7
#     recall    : 0.7070707070707071
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
#        'attribute_53', 'attribute_54', 'attribute_55', 'attribute_56',
#        'attribute_57', 'attribute_58', 'attribute_59', 'attribute_60'],
#       dtype='object')
#     Columns Number : 60
#     precision : 0.7424242424242424
#     f1        : 0.7442455242966752
#     recall    : 0.75
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10',
#        ...
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_59___multiplication',
#        'attribute_58_attribute_60___addition',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___average',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=5370)
#     Columns Number : 5370
#     precision : 0.7525252525252526
#     f1        : 0.7493734335839599
#     recall    : 0.75
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['attribute_6', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_14', 'attribute_15', 'attribute_16', 'attribute_18',
#        'attribute_20', 'attribute_21',
#        ...
#        'attribute_57_attribute_58___multiplication',
#        'attribute_57_attribute_59___average',
#        'attribute_57_attribute_60___addition',
#        'attribute_57_attribute_60___multiplication',
#        'attribute_58_attribute_59___addition',
#        'attribute_58_attribute_59___average',
#        'attribute_58_attribute_60___average',
#        'attribute_58_attribute_60___multiplication',
#        'attribute_59_attribute_60___addition',
#        'attribute_59_attribute_60___multiplication'],
#       dtype='object', length=2622)
#     Columns Number : 2622
#     precision : 0.9444444444444444
#     f1        : 0.948849104859335
#     recall    : 0.9583333333333333
# --------------------------------------------------------------------------------------

# %%
sums = {}
counts = {}

for score in before_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Original Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Original Data:
# precision: 0.7181313131313133
# f1: 0.7168599698524656
# recall: 0.7312373737373739

# %%
sums = {}
counts = {}

for score in all_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated without fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated without fs Data:
# precision: 0.8006565656565655
# f1: 0.798132762423111
# recall: 0.8178904428904428

# %%
sums = {}
counts = {}

for score in selected_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated with fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated with fs Data:
# precision: 0.7963131313131313
# f1: 0.7935604093376002
# recall: 0.8118412143412144

# %%
print(f"Columns generation: {np.mean(columns_number)}")
# Out:
# Columns generation: 2138.7
