# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from gaGen import GenGeneticAlgorithm
import copy

# %%
def evaluate(X_train : pd.DataFrame, y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame, random_state = None):
    
    clf = DecisionTreeClassifier(random_state= random_state)
    
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)
    precision = precision_score(predictions,y_test, average='macro')
    f1 = f1_score(predictions,y_test, average='macro')
    recall = recall_score(predictions,y_test, average='macro')
    
    return {"precision":precision, "f1":f1, "recall":recall}

# %%
dataset_name= "ionosphere"

data = pd.read_csv(f"../Datasets/{dataset_name}.csv")

data.head(10)
# Out:
#    a01  a02      a03      a04      a05      a06      a07      a08      a09  \
# 0    1    0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1    1    0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2    1    0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3    1    0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4    1    0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# 5    1    0  0.02337 -0.00592 -0.09924 -0.11949 -0.00763 -0.11824  0.14706
# 6    1    0  0.97588 -0.10602  0.94601 -0.20800  0.92806 -0.28350  0.85996
# 7    0    0  0.00000  0.00000  0.00000  0.00000  1.00000 -1.00000  0.00000
# 8    1    0  0.96355 -0.07198  1.00000 -0.14333  1.00000 -0.21313  1.00000
# 9    1    0 -0.01864 -0.08459  0.00000  0.00000  0.00000  0.00000  0.11470
#
#        a10  ...      a26      a27      a28      a29      a30      a31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
# 5  0.06637  ... -0.01535 -0.03240  0.09223 -0.07859  0.00732  0.00000
# 6 -0.27342  ... -0.81634  0.13659 -0.82510  0.04606 -0.82395 -0.04262
# 7  0.00000  ...  1.00000  1.00000  1.00000  0.00000  0.00000  1.00000
# 8 -0.36174  ... -0.65440  0.57577 -0.69712  0.25435 -0.63919  0.45114
# 9 -0.26810  ... -0.01326  0.20645 -0.02294  0.00000  0.00000  0.16595
#
#        a32      a33      a34  class
# 0 -0.54487  0.18641 -0.45300      g
# 1 -0.06288 -0.13738 -0.02447      b
# 2 -0.24180  0.56045 -0.38238      g
# 3  1.00000 -0.32382  1.00000      b
# 4 -0.59573 -0.04608 -0.65697      g
# 5  0.00000 -0.00039  0.12011      b
# 6 -0.81318 -0.13832 -0.80975      g
# 7  1.00000  0.00000  0.00000      b
# 8 -0.72779  0.38895 -0.73420      g
# 9  0.24086 -0.08208  0.38065      b
#
# [10 rows x 35 columns]

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state= 42)

before_scores= []
selected_scores= []
all_scores = []
columns_number= []

for index,(train_index, test_index) in enumerate(skf.split(X, y)):
    
    fold_x_train =X.iloc[train_index]
    fold_y_train = y.iloc[train_index]
    
    fold_x_test =X.iloc[test_index]
    fold_y_test = y.iloc[test_index]
    
    score_before = evaluate(fold_x_train, fold_y_train, fold_x_test, fold_y_test)
    before_scores.append(score_before)
    
    print(f'''For the original data:
    Columns : {fold_x_train.columns}
    Columns Number : {len(fold_x_train.columns)} 
    precision : {score_before["precision"]}
    f1        : {score_before["f1"]}
    recall    : {score_before["recall"]}
          ''')
    print("Ga Gen started with inputs ......")
    ga= GenGeneticAlgorithm(
        X_train= fold_x_train,
        X_test= fold_x_test,
        y_train= fold_y_train,
        y_test= fold_y_test,
        rnd_state=42
    )

    selected_new_X_train , selected_new_X_test, all__new_X_train ,all_new_X_test = ga.run(population_size= 20, generation_limit= 10, mutation_probability= 0.1)
    
    print("Ga Gen finished ...")

    score_after= evaluate(all__new_X_train, fold_y_train, all_new_X_test, fold_y_test, 42)
    all_scores.append(score_after)
    
    print(f'''\nFor the new generated data with gaGen without selection:
    Columns : {all_new_X_test.columns}
    Columns Number : {len(all_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
    ''')
    score_after= evaluate(selected_new_X_train, fold_y_train, selected_new_X_test, fold_y_test,42)
    selected_scores.append(score_after)
    
    columns_number.append(len(selected_new_X_test.columns))
    
    print(f'''\nFor the new generated data with gaGen with selection:
    Columns : {selected_new_X_test.columns}
    Columns Number : {len(selected_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
--------------------------------------------------------------------------------------''')
# Out:
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.9565217391304348
#     f1        : 0.9415584415584416
#     recall    : 0.9333333333333333
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.9180602006688963
#     f1        : 0.9111111111111111
#     recall    : 0.9058441558441559
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a02', 'a03', 'a04', 'a07', 'a08', 'a09', 'a10', 'a12', 'a13', 'a14',
#        ...
#        'a30_a31___average', 'a30_a34___addition', 'a30_a34___multiplication',
#        'a31_a32___average', 'a31_a33___average', 'a31_a34___average',
#        'a32_a33___multiplication', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition'],
#       dtype='object', length=483)
#     Columns Number : 483
#     precision : 0.9782608695652174
#     f1        : 0.9703703703703703
#     recall    : 0.9642857142857143
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.8097826086956521
#     f1        : 0.8097826086956521
#     recall    : 0.8097826086956521
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.8297101449275363
#     f1        : 0.8164335664335665
#     recall    : 0.8095238095238095
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a01', 'a04', 'a08', 'a09', 'a10', 'a12', 'a13', 'a14', 'a22', 'a23',
#        ...
#        'a31_a32___average', 'a31_a32___multiplication', 'a31_a33___addition',
#        'a31_a34___addition', 'a32_a33___addition', 'a32_a33___multiplication',
#        'a32_a34___addition', 'a32_a34___average', 'a33_a34___addition',
#        'a33_a34___multiplication'],
#       dtype='object', length=748)
#     Columns Number : 748
#     precision : 0.8931159420289855
#     f1        : 0.8776223776223776
#     recall    : 0.8690476190476191
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.9565217391304348
#     f1        : 0.9388111888111889
#     recall    : 0.9285714285714286
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a06', 'a07', 'a08', 'a09', 'a10', 'a11',
#        ...
#        'a25_a27___average', 'a26_a29___multiplication', 'a27_a28___average',
#        'a27_a34___average', 'a28_a33___addition', 'a28_a34___addition',
#        'a28_a34___multiplication', 'a29_a30___average', 'a29_a32___average',
#        'a29_a33___average'],
#       dtype='object', length=193)
#     Columns Number : 193
#     precision : 0.9583333333333333
#     f1        : 0.967622571692877
#     recall    : 0.9791666666666667
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.8097826086956521
#     f1        : 0.8097826086956521
#     recall    : 0.8097826086956521
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.894927536231884
#     f1        : 0.9028677150786308
#     recall    : 0.9128787878787878
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a02', 'a03', 'a04', 'a05', 'a08', 'a11', 'a12', 'a14', 'a17', 'a20',
#        ...
#        'a25_a30___addition', 'a27_a28___multiplication', 'a28_a32___addition',
#        'a28_a32___average', 'a28_a33___average', 'a29_a30___average',
#        'a29_a32___addition', 'a29_a33___multiplication', 'a30_a33___average',
#        'a30_a33___multiplication'],
#       dtype='object', length=179)
#     Columns Number : 179
#     precision : 0.894927536231884
#     f1        : 0.9028677150786308
#     recall    : 0.9128787878787878
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.9148550724637681
#     f1        : 0.9066666666666667
#     recall    : 0.9003496503496504
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.8532608695652174
#     f1        : 0.8674242424242424
#     recall    : 0.89
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a02', 'a03', 'a07', 'a08', 'a09', 'a10', 'a12', 'a13', 'a14', 'a15',
#        ...
#        'a30_a31___addition', 'a30_a32___addition', 'a30_a33___addition',
#        'a30_a34___addition', 'a31_a32___multiplication', 'a31_a33___addition',
#        'a31_a33___multiplication', 'a32_a34___multiplication',
#        'a33_a34___addition', 'a33_a34___multiplication'],
#       dtype='object', length=850)
#     Columns Number : 850
#     precision : 0.8532608695652174
#     f1        : 0.8674242424242424
#     recall    : 0.89
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.8618881118881119
#     f1        : 0.8731884057971014
#     recall    : 0.8920454545454546
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.8234265734265734
#     f1        : 0.8381128584643849
#     recall    : 0.87
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a03', 'a06', 'a07', 'a08', 'a09', 'a10', 'a11', 'a12', 'a14', 'a16',
#        ...
#        'a28_a33___addition', 'a28_a33___average', 'a29_a30___multiplication',
#        'a29_a32___multiplication', 'a30_a31___average',
#        'a30_a31___multiplication', 'a30_a34___multiplication',
#        'a31_a33___multiplication', 'a31_a34___multiplication',
#        'a32_a34___average'],
#       dtype='object', length=405)
#     Columns Number : 405
#     precision : 0.8846153846153846
#     f1        : 0.9028677150786308
#     recall    : 0.94
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.9388111888111889
#     f1        : 0.9388111888111889
#     recall    : 0.9388111888111889
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.784965034965035
#     f1        : 0.8011363636363636
#     recall    : 0.8482905982905983
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a06', 'a08', 'a09', 'a10', 'a11', 'a12', 'a13',
#        ...
#        'a30_a31___multiplication', 'a30_a33___average',
#        'a30_a33___multiplication', 'a31_a32___average',
#        'a31_a32___multiplication', 'a32_a33___average', 'a32_a34___average',
#        'a33_a34___addition', 'a33_a34___average', 'a33_a34___multiplication'],
#       dtype='object', length=470)
#     Columns Number : 470
#     precision : 0.9003496503496504
#     f1        : 0.9066666666666667
#     recall    : 0.9148550724637681
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.9545454545454546
#     f1        : 0.9404761904761905
#     recall    : 0.9333333333333333
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a01', 'a03', 'a07', 'a08', 'a09', 'a10', 'a11', 'a15', 'a18', 'a19',
#        ...
#        'a30_a32___average', 'a30_a32___multiplication', 'a30_a33___average',
#        'a31_a32___addition', 'a31_a33___addition', 'a31_a33___average',
#        'a31_a34___average', 'a31_a34___multiplication', 'a32_a34___average',
#        'a33_a34___addition'],
#       dtype='object', length=827)
#     Columns Number : 827
#     precision : 0.9772727272727273
#     f1        : 0.9698535745047372
#     recall    : 0.9642857142857143
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.8094405594405594
#     f1        : 0.7939444911690496
#     recall    : 0.7911184210526316
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.8006993006993006
#     f1        : 0.8097826086956521
#     recall    : 0.8257575757575758
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a01', 'a02', 'a05', 'a09', 'a10', 'a11', 'a12', 'a13', 'a14', 'a17',
#        ...
#        'a26_a34___addition', 'a27_a34___addition', 'a27_a34___multiplication',
#        'a28_a29___addition', 'a28_a30___multiplication', 'a28_a34___addition',
#        'a29_a31___addition', 'a29_a32___addition', 'a31_a34___average',
#        'a32_a33___addition'],
#       dtype='object', length=556)
#     Columns Number : 556
#     precision : 0.9388111888111889
#     f1        : 0.9388111888111889
#     recall    : 0.9388111888111889
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        'a11', 'a12', 'a13', 'a14', 'a15', 'a16', 'a17', 'a18', 'a19', 'a20',
#        'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29', 'a30',
#        'a31', 'a32', 'a33', 'a34'],
#       dtype='object')
#     Columns Number : 34
#     precision : 0.7552447552447552
#     f1        : 0.7552447552447552
#     recall    : 0.7552447552447552
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['a01', 'a02', 'a03', 'a04', 'a05', 'a06', 'a07', 'a08', 'a09', 'a10',
#        ...
#        'a31_a34___multiplication', 'a32_a33___addition', 'a32_a33___average',
#        'a32_a33___multiplication', 'a32_a34___addition', 'a32_a34___average',
#        'a32_a34___multiplication', 'a33_a34___addition', 'a33_a34___average',
#        'a33_a34___multiplication'],
#       dtype='object', length=1717)
#     Columns Number : 1717
#     precision : 0.8321678321678322
#     f1        : 0.8214285714285714
#     recall    : 0.8166666666666667
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['a04', 'a07', 'a11', 'a12', 'a14', 'a15', 'a19', 'a20', 'a21', 'a24',
#        ...
#        'a30_a33___addition', 'a30_a33___multiplication', 'a30_a34___average',
#        'a31_a32___addition', 'a31_a32___multiplication', 'a31_a34___addition',
#        'a32_a33___addition', 'a32_a33___average', 'a32_a33___multiplication',
#        'a33_a34___addition'],
#       dtype='object', length=850)
#     Columns Number : 850
#     precision : 0.8548951048951049
#     f1        : 0.8492678725236864
#     recall    : 0.8452380952380952
# --------------------------------------------------------------------------------------

# %%
sums = {}
counts = {}

for score in before_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Original Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Original Data:
# precision: 0.8767393838046011
# f1: 0.8708266545925888
# recall: 0.8692372782633082

# %%
sums = {}
counts = {}

for score in all_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated without fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated without fs Data:
# precision: 0.8737217492652276
# f1: 0.8768297037272523
# recall: 0.8878961593961593

# %%
sums = {}
counts = {}

for score in selected_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated with fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated with fs Data:
# precision: 0.9133842606668694
# f1: 0.9153374294773406
# recall: 0.9218568858677554

# %%
print(f"Columns generation: {np.mean(columns_number)}")
# Out:
# Columns generation: 556.1
