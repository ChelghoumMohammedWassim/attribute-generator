# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from gaGen import GenGeneticAlgorithm
import copy

# %%
def evaluate(X_train : pd.DataFrame, y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame, random_state = None):
    
    clf = DecisionTreeClassifier(random_state= random_state)
    
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)
    precision = precision_score(predictions,y_test, average='macro')
    f1 = f1_score(predictions,y_test, average='macro')
    recall = recall_score(predictions,y_test, average='macro')
    
    return {"precision":precision, "f1":f1, "recall":recall}

# %%
dataset_name= "Heart"

data = pd.read_csv(f"../Datasets/{dataset_name}.csv")

data.replace('?', np.nan, inplace=True)

data.head(10)
# Out:
#    A1  A2  A3   A4   A5  A6  A7   A8  A9  A10  A11  A12  A13  A14
# 0  70   1   4  130  322   0   2  109   0  2.4    2    3    3    2
# 1  67   0   3  115  564   0   2  160   0  1.6    2    0    7    1
# 2  57   1   2  124  261   0   0  141   0  0.3    1    0    7    2
# 3  64   1   4  128  263   0   0  105   1  0.2    2    1    7    1
# 4  74   0   2  120  269   0   2  121   1  0.2    1    1    3    1
# 5  65   1   4  120  177   0   0  140   0  0.4    1    0    7    1
# 6  56   1   3  130  256   1   2  142   1  0.6    2    1    6    2
# 7  59   1   4  110  239   0   2  142   1  1.2    2    1    7    2
# 8  60   1   4  140  293   0   2  170   0  1.2    2    2    7    2
# 9  63   0   4  150  407   0   2  154   0  4.0    2    3    7    2

# %%
X = data.iloc[:, :-1]

y = data.iloc[:, -1]

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state= 42)

before_scores= []
selected_scores= []
all_scores = []
columns_number= []

for index,(train_index, test_index) in enumerate(skf.split(X, y)):
    
    fold_x_train =X.iloc[train_index]
    fold_y_train = y.iloc[train_index]
    
    fold_x_test =X.iloc[test_index]
    fold_y_test = y.iloc[test_index]
    
    score_before = evaluate(fold_x_train, fold_y_train, fold_x_test, fold_y_test)
    before_scores.append(score_before)
    
    print(f'''For the original data:
    Columns : {fold_x_train.columns}
    Columns Number : {len(fold_x_train.columns)} 
    precision : {score_before["precision"]}
    f1        : {score_before["f1"]}
    recall    : {score_before["recall"]}
          ''')
    print("Ga Gen started with inputs ......")
    ga= GenGeneticAlgorithm(
        X_train= fold_x_train,
        X_test= fold_x_test,
        y_train= fold_y_train,
        y_test= fold_y_test,
        rnd_state=None
    )

    selected_new_X_train , selected_new_X_test, all__new_X_train ,all_new_X_test = ga.run(population_size= 20, generation_limit= 20, mutation_probability= 0.1)
    
    print("Ga Gen finished ...")

    score_after= evaluate(all__new_X_train, fold_y_train, all_new_X_test, fold_y_test)
    all_scores.append(score_after)
    
    print(f'''\nFor the new generated data with gaGen without selection:
    Columns : {all_new_X_test.columns}
    Columns Number : {len(all_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
    ''')
    score_after= evaluate(selected_new_X_train, fold_y_train, selected_new_X_test, fold_y_test)
    selected_scores.append(score_after)
    
    columns_number.append(len(selected_new_X_test.columns))
    
    print(f'''\nFor the new generated data with gaGen with selection:
    Columns : {selected_new_X_test.columns}
    Columns Number : {len(selected_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
--------------------------------------------------------------------------------------''')
# Out:
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.8416666666666667
#     f1        : 0.8465909090909092
#     recall    : 0.861764705882353
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.775
#     f1        : 0.775
#     recall    : 0.775
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A6', 'A7', 'A8', 'A9', 'A12', 'A13',
#        'A1_A2___average', 'A1_A4___addition', 'A1_A5___multiplication',
#        'A1_A6___multiplication', 'A1_A7___addition', 'A1_A7___multiplication',
#        'A1_A8___average', 'A1_A9___addition', 'A1_A9___average',
#        'A1_A10___addition', 'A1_A10___multiplication', 'A1_A11___addition',
#        'A1_A11___average', 'A1_A11___multiplication', 'A1_A12___average',
#        'A1_A12___multiplication', 'A1_A13___addition', 'A2_A3___addition',
#        'A2_A3___average', 'A2_A3___multiplication', 'A2_A4___average',
#        'A2_A5___average', 'A2_A5___multiplication', 'A2_A6___average',
#        'A2_A7___multiplication', 'A2_A8___addition', 'A2_A9___average',
#        'A2_A12___average', 'A2_A12___multiplication', 'A3_A4___addition',
#        'A3_A4___average', 'A3_A5___multiplication', 'A3_A6___addition',
#        'A3_A10___addition', 'A3_A11___multiplication', 'A3_A12___average',
#        'A3_A12___multiplication', 'A3_A13___multiplication',
#        'A4_A5___multiplication', 'A4_A7___addition', 'A4_A8___addition',
#        'A4_A10___average', 'A4_A12___average', 'A5_A9___addition',
#        'A5_A9___multiplication', 'A6_A13___addition', 'A7_A10___addition',
#        'A7_A12___average', 'A11_A12___multiplication'],
#       dtype='object')
#     Columns Number : 59
#     precision : 0.7583333333333333
#     f1        : 0.7617647058823529
#     recall    : 0.805921052631579
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.7
#     f1        : 0.7
#     recall    : 0.7
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.825
#     f1        : 0.8148148148148148
#     recall    : 0.825
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A3', 'A8', 'A11', 'A13', 'A1_A2___average', 'A1_A3___addition',
#        'A1_A3___average', 'A1_A5___average', 'A1_A6___average',
#        ...
#        'A10_A11___average', 'A10_A11___multiplication', 'A10_A12___addition',
#        'A10_A12___multiplication', 'A10_A13___addition', 'A10_A13___average',
#        'A10_A13___multiplication', 'A11_A13___addition', 'A12_A13___addition',
#        'A12_A13___multiplication'],
#       dtype='object', length=112)
#     Columns Number : 112
#     precision : 0.6666666666666666
#     f1        : 0.6648275862068966
#     recall    : 0.6648351648351649
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.775
#     f1        : 0.775
#     recall    : 0.775
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.7166666666666667
#     f1        : 0.7032967032967032
#     recall    : 0.7215909090909092
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A8', 'A9', 'A13', 'A1_A2___addition',
#        'A1_A2___multiplication', 'A1_A3___addition', 'A1_A4___multiplication',
#        'A1_A5___average', 'A1_A6___addition', 'A1_A7___average',
#        'A1_A7___multiplication', 'A1_A8___average', 'A1_A8___multiplication',
#        'A1_A9___addition', 'A1_A9___average', 'A1_A10___addition',
#        'A1_A10___average', 'A1_A10___multiplication', 'A1_A11___addition',
#        'A1_A11___multiplication', 'A1_A13___addition',
#        'A1_A13___multiplication', 'A2_A4___addition', 'A2_A4___average',
#        'A2_A5___addition', 'A2_A5___multiplication', 'A2_A6___addition',
#        'A2_A6___average', 'A2_A7___average', 'A2_A9___average',
#        'A2_A10___addition', 'A2_A10___multiplication', 'A2_A12___average',
#        'A2_A12___multiplication', 'A3_A4___multiplication', 'A3_A5___average',
#        'A3_A5___multiplication', 'A3_A6___multiplication', 'A3_A7___average',
#        'A3_A7___multiplication', 'A3_A8___addition', 'A3_A8___average',
#        'A3_A8___multiplication', 'A3_A10___average', 'A3_A11___multiplication',
#        'A3_A12___average', 'A3_A13___multiplication', 'A4_A5___addition',
#        'A4_A5___average', 'A4_A6___multiplication', 'A4_A7___addition',
#        'A4_A7___average', 'A4_A11___multiplication', 'A4_A12___addition',
#        'A5_A8___addition', 'A5_A10___addition', 'A5_A10___multiplication',
#        'A5_A12___addition', 'A5_A13___addition', 'A5_A13___average',
#        'A6_A8___multiplication', 'A6_A9___average', 'A6_A11___multiplication',
#        'A6_A12___addition', 'A7_A9___average', 'A7_A9___multiplication',
#        'A7_A12___multiplication', 'A7_A13___addition', 'A8_A10___average',
#        'A8_A11___addition', 'A8_A11___average', 'A9_A13___average',
#        'A9_A13___multiplication', 'A10_A13___multiplication',
#        'A11_A12___multiplication', 'A12_A13___multiplication'],
#       dtype='object')
#     Columns Number : 80
#     precision : 0.6583333333333333
#     f1        : 0.6591865357643759
#     recall    : 0.6619318181818181
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.575
#     f1        : 0.5714285714285714
#     recall    : 0.5833333333333334
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.7833333333333333
#     f1        : 0.7774725274725275
#     recall    : 0.7802197802197802
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A3', 'A4', 'A7', 'A10', 'A12', 'A1_A2___multiplication',
#        'A1_A3___average', 'A1_A4___addition', 'A1_A4___multiplication',
#        'A1_A5___addition',
#        ...
#        'A9_A11___average', 'A9_A11___multiplication',
#        'A9_A12___multiplication', 'A10_A12___multiplication',
#        'A10_A13___addition', 'A10_A13___average', 'A11_A12___addition',
#        'A11_A12___average', 'A11_A13___multiplication', 'A12_A13___addition'],
#       dtype='object', length=102)
#     Columns Number : 102
#     precision : 0.8083333333333333
#     f1        : 0.8106591865357644
#     recall    : 0.8153409090909092
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.6916666666666667
#     f1        : 0.6931818181818181
#     recall    : 0.7029411764705882
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.5583333333333333
#     f1        : 0.554945054945055
#     recall    : 0.5576923076923077
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A2', 'A3', 'A5', 'A8', 'A10', 'A11', 'A13', 'A1_A2___addition',
#        'A1_A2___average', 'A1_A2___multiplication', 'A1_A4___addition',
#        'A1_A4___average', 'A1_A4___multiplication', 'A1_A7___addition',
#        'A1_A8___addition', 'A1_A10___average', 'A1_A11___addition',
#        'A2_A3___addition', 'A2_A5___average', 'A2_A5___multiplication',
#        'A2_A11___addition', 'A2_A12___average', 'A2_A12___multiplication',
#        'A2_A13___multiplication', 'A3_A4___average', 'A3_A5___average',
#        'A3_A7___average', 'A3_A8___multiplication', 'A3_A12___multiplication',
#        'A3_A13___addition', 'A4_A5___average', 'A4_A7___addition',
#        'A4_A7___average', 'A4_A11___addition', 'A4_A13___addition',
#        'A5_A7___average', 'A5_A10___addition', 'A5_A12___average',
#        'A5_A13___multiplication', 'A6_A7___addition', 'A6_A8___average',
#        'A6_A10___addition', 'A6_A10___average', 'A6_A12___addition',
#        'A6_A12___average', 'A6_A12___multiplication',
#        'A7_A11___multiplication', 'A8_A11___addition',
#        'A8_A12___multiplication', 'A8_A13___multiplication',
#        'A9_A10___addition', 'A9_A13___multiplication', 'A10_A11___addition',
#        'A10_A11___multiplication', 'A10_A12___addition', 'A10_A13___addition',
#        'A10_A13___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A12_A13___addition', 'A12_A13___average', 'A12_A13___multiplication'],
#       dtype='object')
#     Columns Number : 62
#     precision : 0.5583333333333333
#     f1        : 0.554945054945055
#     recall    : 0.5576923076923077
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.8583333333333334
#     f1        : 0.8516483516483516
#     recall    : 0.8543956043956045
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.6916666666666667
#     f1        : 0.6931818181818181
#     recall    : 0.7029411764705882
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A2', 'A4', 'A10', 'A11', 'A12', 'A1_A2___average',
#        'A1_A3___addition', 'A1_A3___average', 'A1_A3___multiplication',
#        ...
#        'A9_A11___multiplication', 'A9_A12___addition', 'A9_A12___average',
#        'A9_A13___average', 'A10_A11___average', 'A11_A12___addition',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=122)
#     Columns Number : 122
#     precision : 0.7
#     f1        : 0.7
#     recall    : 0.7
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.7583333333333333
#     f1        : 0.7617647058823529
#     recall    : 0.805921052631579
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.7250000000000001
#     f1        : 0.7272727272727273
#     recall    : 0.75
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A4', 'A6', 'A8', 'A10', 'A12', 'A1_A2___average',
#        'A1_A2___multiplication', 'A1_A3___multiplication', 'A1_A4___addition',
#        'A1_A4___average',
#        ...
#        'A9_A12___average', 'A9_A12___multiplication', 'A9_A13___addition',
#        'A10_A11___addition', 'A10_A11___multiplication', 'A11_A12___addition',
#        'A11_A13___addition', 'A11_A13___multiplication', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=125)
#     Columns Number : 125
#     precision : 0.7583333333333333
#     f1        : 0.7617647058823529
#     recall    : 0.805921052631579
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.7833333333333333
#     f1        : 0.7774725274725275
#     recall    : 0.7802197802197802
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.7833333333333333
#     f1        : 0.7774725274725275
#     recall    : 0.7802197802197802
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A4', 'A5', 'A7', 'A9', 'A11', 'A1_A2___addition',
#        'A1_A2___multiplication', 'A1_A3___addition', 'A1_A3___average',
#        'A1_A4___addition', 'A1_A5___average', 'A1_A5___multiplication',
#        'A1_A6___addition', 'A1_A6___multiplication', 'A1_A7___addition',
#        'A1_A8___multiplication', 'A1_A10___addition',
#        'A1_A10___multiplication', 'A1_A11___addition',
#        'A1_A11___multiplication', 'A1_A13___addition', 'A1_A13___average',
#        'A2_A3___addition', 'A2_A5___addition', 'A2_A6___addition',
#        'A2_A6___average', 'A2_A8___multiplication', 'A2_A9___addition',
#        'A2_A9___average', 'A2_A9___multiplication', 'A2_A10___addition',
#        'A2_A10___multiplication', 'A2_A11___addition', 'A2_A12___average',
#        'A2_A13___average', 'A3_A4___average', 'A3_A5___addition',
#        'A3_A5___average', 'A3_A6___average', 'A3_A6___multiplication',
#        'A3_A7___addition', 'A3_A7___average', 'A3_A7___multiplication',
#        'A3_A8___addition', 'A3_A8___multiplication', 'A3_A9___addition',
#        'A3_A9___average', 'A3_A10___average', 'A3_A11___addition',
#        'A3_A11___average', 'A3_A11___multiplication', 'A3_A13___addition',
#        'A3_A13___average', 'A3_A13___multiplication', 'A4_A5___multiplication',
#        'A4_A6___addition', 'A4_A7___multiplication', 'A4_A10___addition',
#        'A4_A10___multiplication', 'A4_A11___addition', 'A4_A11___average',
#        'A6_A8___multiplication', 'A6_A10___addition',
#        'A6_A12___multiplication', 'A6_A13___average', 'A7_A8___average',
#        'A7_A10___addition', 'A7_A12___addition', 'A7_A12___multiplication',
#        'A8_A9___average', 'A8_A11___average', 'A8_A12___average',
#        'A9_A12___multiplication'],
#       dtype='object')
#     Columns Number : 74
#     precision : 0.775
#     f1        : 0.775
#     recall    : 0.775
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.775
#     f1        : 0.775
#     recall    : 0.775
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.6666666666666666
#     f1        : 0.6648275862068966
#     recall    : 0.6648351648351649
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A9', 'A10', 'A13',
#        'A1_A2___addition', 'A1_A4___average', 'A1_A6___average',
#        'A1_A7___addition', 'A1_A7___average', 'A1_A9___multiplication',
#        'A1_A12___addition', 'A2_A3___multiplication', 'A2_A8___addition',
#        'A2_A8___average', 'A2_A8___multiplication', 'A2_A10___multiplication',
#        'A2_A11___addition', 'A2_A11___multiplication',
#        'A3_A4___multiplication', 'A3_A7___multiplication', 'A3_A9___addition',
#        'A3_A9___average', 'A3_A11___average', 'A3_A12___average',
#        'A4_A7___average', 'A4_A10___addition', 'A4_A11___addition',
#        'A4_A13___addition', 'A4_A13___multiplication',
#        'A5_A7___multiplication', 'A5_A8___addition', 'A5_A11___average',
#        'A5_A12___addition', 'A6_A7___addition', 'A6_A9___multiplication',
#        'A6_A10___average', 'A6_A13___addition', 'A7_A11___average',
#        'A7_A12___average', 'A8_A9___addition', 'A8_A10___addition',
#        'A8_A11___addition', 'A8_A12___average', 'A9_A10___average',
#        'A9_A11___addition', 'A9_A12___addition', 'A9_A12___average',
#        'A9_A12___multiplication', 'A10_A11___multiplication',
#        'A11_A13___multiplication'],
#       dtype='object')
#     Columns Number : 55
#     precision : 0.775
#     f1        : 0.775
#     recall    : 0.775
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11',
#        'A12', 'A13'],
#       dtype='object')
#     Columns Number : 13
#     precision : 0.9333333333333333
#     f1        : 0.9258241758241759
#     recall    : 0.9285714285714286
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
#        ...
#        'A10_A13___multiplication', 'A11_A12___addition', 'A11_A12___average',
#        'A11_A12___multiplication', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___addition', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object', length=247)
#     Columns Number : 247
#     precision : 0.8833333333333333
#     f1        : 0.8863955119214586
#     recall    : 0.8920454545454546
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['A2', 'A3', 'A4', 'A5', 'A6', 'A9', 'A10', 'A13', 'A1_A2___addition',
#        'A1_A2___multiplication', 'A1_A3___average', 'A1_A3___multiplication',
#        'A1_A4___addition', 'A1_A4___average', 'A1_A4___multiplication',
#        'A1_A5___addition', 'A1_A5___multiplication', 'A1_A6___multiplication',
#        'A1_A7___addition', 'A1_A7___multiplication', 'A1_A8___multiplication',
#        'A1_A10___addition', 'A1_A11___average', 'A1_A12___average',
#        'A1_A12___multiplication', 'A1_A13___addition', 'A2_A4___addition',
#        'A2_A4___multiplication', 'A2_A5___average', 'A2_A9___addition',
#        'A2_A11___average', 'A3_A8___average', 'A3_A12___average',
#        'A4_A8___multiplication', 'A4_A9___average', 'A4_A12___average',
#        'A4_A13___addition', 'A5_A9___multiplication', 'A5_A10___addition',
#        'A5_A12___multiplication', 'A6_A9___addition', 'A6_A12___average',
#        'A6_A13___addition', 'A7_A9___average', 'A7_A13___addition',
#        'A8_A10___addition', 'A8_A10___average', 'A8_A11___average',
#        'A8_A11___multiplication', 'A9_A10___addition', 'A9_A10___average',
#        'A9_A11___multiplication', 'A9_A12___addition', 'A9_A12___average',
#        'A9_A12___multiplication', 'A9_A13___average', 'A10_A12___average',
#        'A10_A13___average', 'A10_A13___multiplication', 'A11_A12___addition',
#        'A11_A12___average', 'A11_A13___addition', 'A11_A13___average',
#        'A11_A13___multiplication', 'A12_A13___average',
#        'A12_A13___multiplication'],
#       dtype='object')
#     Columns Number : 66
#     precision : 0.925
#     f1        : 0.925
#     recall    : 0.925
# --------------------------------------------------------------------------------------

# %%
sums = {}
counts = {}

for score in before_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Original Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Original Data:
# precision: 0.7691666666666667
# f1: 0.7677911059528707
# recall: 0.7767147081504666

# %%
sums = {}
counts = {}

for score in all_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated without fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated without fs Data:
# precision: 0.7408333333333333
# f1: 0.7374679271584528
# recall: 0.7449544573073986

# %%
sums = {}
counts = {}

for score in selected_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated with fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated with fs Data:
# precision: 0.7383333333333334
# f1: 0.7388147775216798
# recall: 0.7486642305063358

# %%
print(f"Columns generation: {np.mean(columns_number)}")
# Out:
# Columns generation: 85.7
