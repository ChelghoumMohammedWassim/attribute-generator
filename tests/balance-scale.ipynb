# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from gaGen import GenGeneticAlgorithm
import copy

# %%
def evaluate(X_train : pd.DataFrame, y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame, random_state = None):
    
    clf = DecisionTreeClassifier(random_state= random_state)
    
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)
    precision = precision_score(predictions,y_test, average='macro')
    f1 = f1_score(predictions,y_test, average='macro')
    recall = recall_score(predictions,y_test, average='macro')
    
    return {"precision":precision, "f1":f1, "recall":recall}

# %%
dataset_name= "balance-scale"

data = pd.read_csv(f"../Datasets/{dataset_name}.csv")

data.head(10)
# Out:
#    L-Weight  L-Distance  R-Weight  R-Distance Class
# 0         1           1         1           1     B
# 1         1           1         1           2     R
# 2         1           1         1           3     R
# 3         1           1         1           4     R
# 4         1           1         1           5     R
# 5         1           1         2           1     R
# 6         1           1         2           2     R
# 7         1           1         2           3     R
# 8         1           1         2           4     R
# 9         1           1         2           5     R

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state= 42)

before_scores= []
selected_scores= []
all_scores = []
columns_number= []

for index,(train_index, test_index) in enumerate(skf.split(X, y)):
    
    fold_x_train =X.iloc[train_index]
    fold_y_train = y.iloc[train_index]
    
    fold_x_test =X.iloc[test_index]
    fold_y_test = y.iloc[test_index]
    
    score_before = evaluate(fold_x_train, fold_y_train, fold_x_test, fold_y_test)
    before_scores.append(score_before)
    
    print(f'''For the original data:
    Columns : {fold_x_train.columns}
    Columns Number : {len(fold_x_train.columns)} 
    precision : {score_before["precision"]}
    f1        : {score_before["f1"]}
    recall    : {score_before["recall"]}
          ''')
    print("Ga Gen started with inputs ......")
    ga= GenGeneticAlgorithm(
        X_train= fold_x_train,
        X_test= fold_x_test,
        y_train= fold_y_train,
        y_test= fold_y_test,
        rnd_state=None
    )

    selected_new_X_train , selected_new_X_test, all__new_X_train ,all_new_X_test = ga.run(population_size= 30, generation_limit= 50, mutation_probability= 0.1)
    
    print("Ga Gen finished ...")

    score_after= evaluate(all__new_X_train, fold_y_train, all_new_X_test, fold_y_test)
    all_scores.append(score_after)
    
    print(f'''\nFor the new generated data with gaGen without selection:
    Columns : {all_new_X_test.columns}
    Columns Number : {len(all_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
    ''')
    score_after= evaluate(selected_new_X_train, fold_y_train, selected_new_X_test, fold_y_test)
    selected_scores.append(score_after)
    
    columns_number.append(len(selected_new_X_test.columns))
    
    print(f'''\nFor the new generated data with gaGen with selection:
    Columns : {selected_new_X_test.columns}
    Columns Number : {len(selected_new_X_test.columns)} 
    precision : {score_after["precision"]}
    f1        : {score_after["f1"]}
    recall    : {score_after["recall"]}
--------------------------------------------------------------------------------------''')
# Out:
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5057471264367815
#     f1        : 0.5333333333333333
#     recall    : 0.5641025641025641
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.8321839080459771
#     f1        : 0.8190256071612003
#     recall    : 0.8098765432098766
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___multiplication', 'R-Weight_R-Distance___multiplication'], dtype='object')
#     Columns Number : 2
#     precision : 0.9333333333333332
#     f1        : 0.9573132454488387
#     recall    : 0.9888888888888889
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5517241379310345
#     f1        : 0.5563621697922968
#     recall    : 0.5611658456486043
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.8758620689655171
#     f1        : 0.8209918736234525
#     recall    : 0.801994301994302
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 4
#     precision : 0.9770114942528735
#     f1        : 0.9325396825396827
#     recall    : 0.9047619047619048
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5977011494252874
#     f1        : 0.6027037933817595
#     recall    : 0.608641975308642
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.8436781609195402
#     f1        : 0.8438695609079195
#     recall    : 0.8444444444444444
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___average',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 5
#     precision : 0.9218390804597701
#     f1        : 0.9218356626028349
#     recall    : 0.9222222222222222
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.6091954022988505
#     f1        : 0.6036299765807963
#     recall    : 0.6003086419753086
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.6436781609195402
#     f1        : 0.6276836158192091
#     recall    : 0.6125448028673836
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___multiplication', 'R-Weight_R-Distance___multiplication'], dtype='object')
#     Columns Number : 2
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5057471264367815
#     f1        : 0.538047138047138
#     recall    : 0.5748717948717949
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.8436781609195402
#     f1        : 0.8608187134502924
#     recall    : 0.8844086021505376
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___average', 'L-Weight_L-Distance___multiplication',
#        'L-Weight_R-Weight___average', 'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 4
#     precision : 0.9333333333333332
#     f1        : 0.9573132454488387
#     recall    : 0.9888888888888889
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5730706075533661
#     f1        : 0.5833333333333334
#     recall    : 0.5943562610229277
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.9880952380952381
#     f1        : 0.9636363636363635
#     recall    : 0.9444444444444445
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___average',
#        'L-Distance_R-Weight___average', 'R-Weight_R-Distance___addition',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 5
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5845648604269295
#     f1        : 0.5907756813417191
#     recall    : 0.5995698924731183
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 6
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5611658456486043
#     f1        : 0.5565656565656566
#     recall    : 0.5527678215850259
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.9333333333333332
#     f1        : 0.9571150097465887
#     recall    : 0.9885057471264368
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['R-Weight', 'L-Weight_L-Distance___multiplication',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 5
#     precision : 0.9333333333333332
#     f1        : 0.9571150097465887
#     recall    : 0.9885057471264368
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.5500821018062397
#     f1        : 0.5696969696969697
#     recall    : 0.5911680911680911
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight', 'L-Weight_L-Distance___multiplication',
#        'L-Weight_R-Weight___addition', 'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 4
#     precision : 1.0
#     f1        : 1.0
#     recall    : 1.0
# --------------------------------------------------------------------------------------
# For the original data:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance'], dtype='object')
#     Columns Number : 4
#     precision : 0.6206896551724138
#     f1        : 0.6157894736842106
#     recall    : 0.6117511520737328
#
# Ga Gen started with inputs ......
# Ga Gen finished ...
#
# For the new generated data with gaGen without selection:
#     Columns : Index(['L-Weight', 'L-Distance', 'R-Weight', 'R-Distance',
#        'L-Weight_L-Distance___addition', 'L-Weight_L-Distance___average',
#        'L-Weight_L-Distance___multiplication', 'L-Weight_R-Weight___addition',
#        'L-Weight_R-Weight___average', 'L-Weight_R-Weight___multiplication',
#        'L-Weight_R-Distance___addition', 'L-Weight_R-Distance___average',
#        'L-Weight_R-Distance___multiplication',
#        'L-Distance_R-Weight___addition', 'L-Distance_R-Weight___average',
#        'L-Distance_R-Weight___multiplication',
#        'L-Distance_R-Distance___addition', 'L-Distance_R-Distance___average',
#        'L-Distance_R-Distance___multiplication',
#        'R-Weight_R-Distance___addition', 'R-Weight_R-Distance___average',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 22
#     precision : 0.8218390804597702
#     f1        : 0.8401837928153717
#     recall    : 0.8673835125448028
#
#
# For the new generated data with gaGen with selection:
#     Columns : Index(['L-Weight', 'L-Weight_L-Distance___multiplication',
#        'L-Weight_R-Distance___average', 'L-Distance_R-Distance___addition',
#        'R-Weight_R-Distance___multiplication'],
#       dtype='object')
#     Columns Number : 5
#     precision : 0.8218390804597702
#     f1        : 0.8401837928153717
#     recall    : 0.8673835125448028
# --------------------------------------------------------------------------------------

# %%
sums = {}
counts = {}

for score in before_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Original Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Original Data:
# precision: 0.5659688013136288
# f1: 0.5750237525757214
# recall: 0.585870404022981

# %%
sums = {}
counts = {}

for score in all_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated without fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated without fs Data:
# precision: 0.8782348111658458
# f1: 0.8733324537160397
# recall: 0.8753602398782228

# %%
sums = {}
counts = {}

for score in selected_scores:
    for key, value in score.items():
        sums[key] = sums.get(key, 0) + value
        counts[key] = counts.get(key, 0) + 1

means = {key: sums[key] / counts[key] for key in sums}

print("Generated with fs Data:")
for prop, mean in means.items():
    print(prop + ":", mean)
# Out:
# Generated with fs Data:
# precision: 0.9520689655172415
# f1: 0.9566300638602157
# recall: 0.9660651164433146

# %%
print(f"Columns generation: {np.mean(columns_number)}")
# Out:
# Columns generation: 4.2
